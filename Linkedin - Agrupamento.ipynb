# %% [markdown]
# ### Linkedin - Empresas em que trabalham os meus contatos

# %%
CSV_FILE = 'C:/Users/aluno/Desktop/RIWRS/LINKEDIN/dados/Connections.csv'

# %%
from prettytable import PrettyTable
import sys
import nltk
import csv


# Handle any known abbreviations,
# strip off common suffixes, etc.

transforms = [(', Inc.', ''), (', Inc', ''), (', LLC', ''), (', LLP', '')]

csvReader = csv.DictReader(open(CSV_FILE,encoding="utf8"), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]
companies = [c['Company'].strip() for c in contacts if c['Company'].strip() != '']

for i in range(len(companies)):
    for transform in transforms:
        companies[i] = companies[i].replace(*transform)

ufu = 'Universidade Federal de Uberlândia'      
iftm = 'Instituto Federal de Educação, Ciência e Tecnologia do Triângulo Mineiro'
puc = 'Pontifícia Universidade Católica de Minas Gerais'
zup = 'Zup Innovation'
standardize = [('Federal University of Uberlandia', ufu), 
               ('UFU - Universidade Federal de Uberlândia', ufu), 
               ('Universidade Federal de Uberlândia - UFU', ufu), 
               ('IFTM - Inst. Fed. de Educação, Ciência e Tecnologia do Triângulo Mineiro', iftm),
               ('Federal University of Uberlândia',ufu),
               ('Universidade Federal de Uberlandia',ufu),
               ('Instituto Federal de Minas Gerais',iftm),
               ('Instituto Federal Minas Gerais',iftm),
               ('UFU',ufu),
               ('PUC Minas',puc),
               ('Zup It Innovation',zup),
               ('Zup - Connect & Transform',zup)
              ]
for i in range(len(companies)):
    for standard in standardize:
        companies[i] = companies[i].replace(standard[0],standard[1])

        
        
pt = PrettyTable(['Company', 'Freq'])

pt.align['Company'] = 'l'
fdist = nltk.FreqDist(companies)
[pt.add_row([company, freq]) for (company, freq) in fdist.items() if freq > 1]
pt = pt.get_string(sortby="Freq", reversesort=True)
print(pt)
# Out:
# +---------------------------------------+------+
# | Company                               | Freq |
# +---------------------------------------+------+
# | Sankhya Gestão de Negócios            |  21  |
# | Universidade Federal de Uberlândia    |  15  |
# | Martins                               |  10  |
# | Algar Telecom                         |  9   |
# | Softbox - Soluções Inteligentes em TI |  8   |
# | Zup Innovation                        |  7   |
# | Neppo Tecnologia da Informação        |  7   |
# | Cedro Technologies                    |  6   |
# | everis                                |  5   |
# | XTRATEGIE                             |  5   |
# | ValeCard                              |  5   |
# | Kyros Tecnologia                      |  4   |
# | Algar Tech                            |  4   |
# | Landix Sistemas                       |  3   |
# | Xtrategie                             |  2   |
# | Usina Açucareira Guaíra               |  2   |
# | Up Brasil                             |  2   |
# | Prefeitura Municipal de Uberlândia    |  2   |
# | Morpheus Tecnologia                   |  2   |
# | Escritório de Advocacia               |  2   |
# | Autônomo                              |  2   |
# +---------------------------------------+------+

# %% [markdown]
# ### Linkedin - Cargos que ocupam os meus contatos

# %%
import sys
import nltk
import csv
from prettytable import PrettyTable

professor = 'Professor de Ensino Superior'
professor_basico = 'Professor'
analista_ti = 'Analista de Sistemas'
engenheiro_sw = 'Engenheiro de Software'
transforms = [
    ('Sr.', 'Senior'),
    ('Sr', 'Senior'),
    ('Jr.', 'Junior'),
    ('Jr', 'Junior'),
    ('CEO', 'Chief Executive Officer'),
    ('COO', 'Chief Operating Officer'),
    ('CTO', 'Chief Technology Officer'),
    ('CFO', 'Chief Finance Officer'),
    ('VP', 'Vice President'),
    ('Full Professor',professor),
    ('Professor Dedicação Exclusiva',professor),
    ('Professor Adjunto nível A',professor),
    ('Associate Professor',professor),
    ('Full Time Professor',professor),
    ('Professora Assistente',professor),
    ('Professor adjunto',professor),
    ('Professor do Magistério Superior',professor),
    ('Professora Adjunto',professor),
    ('Professora',professor),
    ('Adjunct Professor',professor),
    ('Professor de Ensino Superior',professor),
    ('Docente',professor_basico),
    #('Professor',professor_basico),
    ('Analista de TI',analista_ti),
    ('Systems Analyst',analista_ti),
    ('Analista de Sistemas, Especialista',analista_ti),
    ('Analista de TI - Administradora Siebel',analista_ti),
    ('Senior System Development Analyst C++',analista_ti),
    ('Analista Desenvolvedor de Sistemas',analista_ti),
    ('Analista de sistemas',analista_ti),
    ('Analista de Sistemas Especialista',analista_ti),
    ('System Analyst and Senior Full-Stack Developer',analista_ti),
    ('Analista de TI Pleno',analista_ti),
    ('Information Technology Analyst',analista_ti),
    ('Analista de sistema',analista_ti),
    ('Desenvolvedor e Analista de Sistemas',analista_ti),
    ('Analista Programador',analista_ti),
    ('Analista de Desenvolvimento de Sistemas',analista_ti),
    ('Analista de desenvolvimento de software',analista_ti),
    ('Analista de Tecnologia da Informação',analista_ti),
    ('System Analyst',analista_ti),
    ('Software Engineer',engenheiro_sw),
    ('Software Engineering',engenheiro_sw),
    ('System Software Engineer',engenheiro_sw),
    ('Software engineer',engenheiro_sw),
    ('Senior Software Engineer Team Lead',engenheiro_sw),
    ('Senior C++ Software Engineer',engenheiro_sw),
    ('Engenheiro de software',engenheiro_sw),
    ('Senior Engenheiro de Software',engenheiro_sw),
    ('System Engenheiro de Software',engenheiro_sw),
    ('Software Developer',engenheiro_sw),
    ('Desenvolvedor',engenheiro_sw),
    ('Analista Desenvolvedor',engenheiro_sw),
    ('Analista Engenheiro de Software',engenheiro_sw),
    ('Software Development Engineer',engenheiro_sw),
    ('Senior C++ Engenheiro de Software',engenheiro_sw),
    ('Engenheiro de Software na ZUP',engenheiro_sw),
    ('Staff Engenheiro de Software',engenheiro_sw)
    
    ]

csvReader = csv.DictReader(open(CSV_FILE,encoding="utf8"), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]

# Read in a list of titles and split apart
# any combined titles like "President/CEO"
# Other variations could be handled as well such
# as "President & CEO", "President and CEO", etc.

titles = []
for contact in contacts:
    titles.extend([t.strip() for t in contact['Position'].split('/')
                  if contact['Position'].strip() != ''])

# Replace common/known abbreviations

for i in range(len(titles)):
    for transform in transforms:
        titles[i] = titles[i].replace(*transform)

# Print out a table of titles sorted by frequency

pt = PrettyTable(['Position', 'Freq'])
pt.align['Position'] = 'l'
titles_fdist = nltk.FreqDist(titles)
[pt.add_row([title, freq]) for (title, freq) in titles_fdist.items() if freq > 1]
pt = pt.get_string(sortby="Freq", reversesort=True)
print(pt)

# Print out a table of tokens sorted by frequency

tokens = []
for title in titles:
    tokens.extend([t.strip(',') for t in title.split()])
pt = PrettyTable(['Token', 'Freq'])
pt.align['Token'] =  'l'
tokens_fdist = nltk.FreqDist(tokens)
[pt.add_row([token, freq]) for (token, freq) in tokens_fdist.items() if freq > 1
 and len(token) > 2]
pt = pt.get_string(sortby="Freq", reversesort=True)
print(pt)
# Out:
# +------------------------------------+------+
# | Position                           | Freq |
# +------------------------------------+------+
# | Analista de Sistemas               |  21  |
# | Engenheiro de Software             |  16  |
# | Professor                          |  5   |
# | Estagiário                         |  4   |
# | Professor de Ensino Superior       |  3   |
# | Engenheiro de Software Java        |  3   |
# | Analista de Recursos Humanos       |  3   |
# | Front-End Engineer                 |  2   |
# | Estudante                          |  2   |
# | Engenheiro de Software de software |  2   |
# | DBA                                |  2   |
# | Chief Technology Officer           |  2   |
# | Chief Executive Officer            |  2   |
# | Bolsista                           |  2   |
# | Arquiteto de Software              |  2   |
# | Analista de Sistemas Júnior        |  2   |
# +------------------------------------+------+
# +-----------------+------+
# | Token           | Freq |
# +-----------------+------+
# | Analista        |  60  |
# | Engenheiro      |  38  |
# | Software        |  33  |
# | Sistemas        |  31  |
# | Gerente         |  15  |
# | Professor       |  13  |
# | Humanos         |  7   |
# | Consultor       |  7   |
# | Técnico         |  6   |
# | Sales           |  6   |
# | Officer         |  6   |
# | Chief           |  6   |
# | Sênior          |  5   |
# | Supervisor      |  5   |
# | Recursos        |  5   |
# | Manager         |  5   |
# | Java            |  5   |
# | Estagiário      |  5   |
# | Diretor         |  5   |
# | Developer       |  5   |
# | Coordenador     |  5   |
# | Assistente      |  5   |
# | Analyst         |  5   |
# | software        |  4   |
# | Supervisora     |  4   |
# | Superior        |  4   |
# | Senior          |  4   |
# | Executive       |  4   |
# | Ensino          |  4   |
# | Administrativo  |  4   |
# | web             |  3   |
# | vendas          |  3   |
# | desenvolvimento |  3   |
# | administrativo  |  3   |
# | Technology      |  3   |
# | Suporte         |  3   |
# | Representante   |  3   |
# | Marketing       |  3   |
# | Júnior          |  3   |
# | Head            |  3   |
# | Founder         |  3   |
# | Desenvolvimento |  3   |
# | Dados           |  3   |
# | Comercial       |  3   |
# | Chefe           |  3   |
# | Auxiliar        |  3   |
# | Arquiteto       |  3   |
# | Administrador   |  3   |
# | suporte         |  2   |
# | sistemas        |  2   |
# | recursos        |  2   |
# | proprietário    |  2   |
# | humanos         |  2   |
# | and             |  2   |
# | Web             |  2   |
# | Trainee         |  2   |
# | Test            |  2   |
# | Telecom         |  2   |
# | Tecnologia      |  2   |
# | Talentos        |  2   |
# | Sócio           |  2   |
# | Seleção         |  2   |
# | Recrutamento    |  2   |
# | Projetos        |  2   |
# | Programador     |  2   |
# | Processos       |  2   |
# | President       |  2   |
# | Pleno           |  2   |
# | Operações       |  2   |
# | Operations      |  2   |
# | Negócios        |  2   |
# | Manutenção      |  2   |
# | Junior          |  2   |
# | Intelligence    |  2   |
# | Infraestrutura  |  2   |
# | Informação      |  2   |
# | Information     |  2   |
# | Fundador        |  2   |
# | Front-End       |  2   |
# | Executivo       |  2   |
# | Estudante       |  2   |
# | Engineer        |  2   |
# | ERP             |  2   |
# | Departamento    |  2   |
# | DBA             |  2   |
# | Coordinator     |  2   |
# | Controle        |  2   |
# | Contas          |  2   |
# | Comunicação     |  2   |
# | CONSULTOR       |  2   |
# | Business        |  2   |
# | Bolsista        |  2   |
# | Banco           |  2   |
# | Angular         |  2   |
# +-----------------+------+

# %% [markdown]
# ### Linkedin - Clusterizando meus contatos por cargos

# %%
# -*- coding: utf-8 -*-

import sys
import csv
from nltk.metrics.distance import masi_distance
from nltk.metrics.distance import jaccard_distance


DISTANCE_THRESHOLD = 0.67
DISTANCE = jaccard_distance

#DISTANCE_THRESHOLD = 0.2
#DISTANCE = masi_distance


def cluster_contacts_by_title(csv_file):
   

    #separators = ['/', 'and', '&', 'de', '-', 'e', ' ']
    separators = ['/', 'and', '&', '-', 'de']

    csvReader = csv.DictReader(open(csv_file,encoding="utf8"), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]

    # Normalize and/or replace known abbreviations
    # and build up list of common titles

    all_titles = []
    for i in range(len(contacts)):
        if contacts[i]['Position'] == '':
            contacts[i]['Position'] = ['']
            continue
        titles = [contacts[i]['Position']]
        for title in titles:
            for seperator in separators:
                if title.find(seperator) >= 0:
                    if title in titles:
                        titles.remove(title)
                    titles.extend([title.strip() for title in title.split(seperator)
                                   if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
        contacts[i]['Position'] = titles
        all_titles.extend(titles)

    all_titles = list(set(all_titles))

    clusters = {}
    for title1 in all_titles:
        clusters[title1] = []
        for title2 in all_titles:
            if title2 in clusters[title1] or title2 in clusters and title1 \
                in clusters[title2]:
                continue
            distance = DISTANCE(set(title1.split()), set(title2.split()))
            ##print(distance, set(title1.split()), set(title2.split()))
            if distance < DISTANCE_THRESHOLD:
                clusters[title1].append(title2)


    clusters = [clusters[title] for title in clusters if len(clusters[title]) > 1]
    
    # Round up contacts who are in these clusters and group them together

    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Position']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('%s %s.'
                                                              % (contact['First Name'], contact['Last Name'][0]))

    return clustered_contacts


if __name__ == '__main__':
    clustered_contacts = cluster_contacts_by_title(CSV_FILE)

    for titles in clustered_contacts:
        common_titles_heading = 'Common Positions: ' + ', '.join(titles)
        
        descriptive_terms = set(titles[0].split())
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))
        descriptive_terms_heading = 'Descriptive Terms: ' \
                                    + ', '.join(descriptive_terms)
        print(descriptive_terms_heading)
        print('-' * max(len(descriptive_terms_heading), len(common_titles_heading)))
        print('\n'.join(clustered_contacts[titles]))
        print()
# Out:
# Descriptive Terms: Operações
# -------------------------------------------
# Davi C.
# Rodrigo A.
#
# Descriptive Terms: Engenheiro
# -------------------------------------------------------------------------------------------
# José Anceloann L.
# Frederico M.
# Renan F.
# Mateus Sebastião G.
#
# Descriptive Terms: Professor
# -----------------------------------------------------------------------------------------
# Marcelo R.
# Maria Adriana V.
# Luiz Gustavo M.
# Alexsandro S.
# Mauricio E.
# Vitor C.
# Ivan R.
# Igor M.
# Cassio P.
#
# Descriptive Terms: Sales
# ---------------------------------------------------
# Frederico M.
# André Felipe R.
#
# Descriptive Terms: Engenheiro
# -------------------------------------------------------------------------
# José Anceloann L.
# Frederico M.
# Mateus Sebastião G.
#
# Descriptive Terms: Software
# --------------------------------------------------
# Laura B.
# Wender O.
# Arthur C.
# Deivisson P.
# Felipe F.
# Lucas A.
# Leonardo P.
# Hugo P.
# Gildo V.
# Tiago M.
# João Pedro R.
# Arthur A.
# Bruno M.
# Pedro L.
# Guilherme D.
# Rafaela S.
# Guilherme P.
# Cristopher M.
# Gustavo F.
# Willian de Freitas O.
# Flavia O.
#
# Descriptive Terms: Front
# ----------------------------------
# Heldson L.
# Eduardo G.
# Artur A.
#
# Descriptive Terms: Fundador
# -------------------------------------------
# Leandro M.
# Igor B.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Pedro Henrique P.
# Ricardo P.
# Ricardo P.
# Arthur D.
# Guilherme C.
# Nielsen G.
# Marco Túlio Z.
# Jonnathan R.
#
# Descriptive Terms: Suporte
# ---------------------------------------------
# Jennipher T.
# Pedro C.
#
# Descriptive Terms: Intelligence, Business
# -----------------------------------------------------------------------------
# Ewerton L.
# Letícia M.
#
# Descriptive Terms: Engenheiro, de
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Laura B.
# Wender O.
# Douglas L.
# Arthur C.
# Deivisson P.
# Felipe F.
# Lucas A.
# Leonardo P.
# Hugo P.
# Josiemerson S.
# Andrêssa F.
# Tiago M.
# Luiz Felipe M.
# Guilherme C.
# Alana R.
# Wellyton M.
# Arthur A.
# Nielsen G.
# Bruno M.
# Vítor P.
# Pedro L.
# Johnata F.
# Guilherme D.
# Rafaela S.
# Guilherme P.
# Cristopher M.
# Augusto M.
# Gustavo F.
# Willian de Freitas O.
# João Pedro F.
# Gabriel M.
# Lucas M.
# Flavia O.
#
# Descriptive Terms: Representante
# --------------------------------------------------------
# Guilherme I.
# Guilherme B.
# Pedro C.
#
# Descriptive Terms: Manager
# ----------------------------------------------------------------------------
# Maurilio C.
# Jose M.
# João Pedro G.
# Lucas R.
#
# Descriptive Terms: Tecnologia, Informação, da
# -------------------------------------------------------------------------------------------
# Cruz E.
# Danielle G.
#
# Descriptive Terms: Engenheiro
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Laura B.
# Wender O.
# Douglas L.
# Arthur C.
# Deivisson P.
# Felipe F.
# Lucas A.
# Leonardo P.
# Hugo P.
# Josiemerson S.
# José Anceloann L.
# Andrêssa F.
# Tiago M.
# Guilherme B.
# Luiz Felipe M.
# Guilherme C.
# Alana R.
# Wellyton M.
# Arthur A.
# Nielsen G.
# Bruno M.
# Vítor P.
# Pedro L.
# Johnata F.
# Guilherme D.
# Rafaela S.
# Guilherme P.
# Cristopher M.
# Augusto M.
# Gustavo F.
# Willian de Freitas O.
# João Pedro F.
# Lucas M.
# Flavia O.
#
# Descriptive Terms: nador
# --------------------------------------------
# Anderson R.
# Bruno R.
# Heverton M.
#
# Descriptive Terms: Manager
# ------------------------------------------------------------------------------------
# Marcos L.
# Maurilio C.
# Jose M.
# Lucas R.
#
# Descriptive Terms: Desenvolvimento
# ----------------------------------------------------------------------------------------------------------------------------
# Arthur D.
# Arthur D.
# Pedro de Freitas S.
# Ana Carolina F.
#
# Descriptive Terms: Manager
# --------------------------------------------------
# Maurilio C.
# Lucas R.
#
# Descriptive Terms: Angular
# ----------------------------------------
# Pedro P.
# Pedro P.
# Lucas M.
#
# Descriptive Terms:
# ------------------------------------------------------------------
# Juliano O.
# Layson D.
# Gustavo S.
# Arthur Kenji I.
# Silas M.
#
# Descriptive Terms: Desenvolvimento
# --------------------------------------------------------------------
# Pedro de Freitas S.
# Ana Carolina F.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------
# Bárbara R.
# Cláudia S.
# Heverton M.
# Ana Carolina F.
#
# Descriptive Terms: Professor
# --------------------------------------------------------------------
# Marcelo R.
# Maria Adriana V.
# Luiz Gustavo M.
# Alexsandro S.
# Mauricio E.
# Vitor C.
# Igor M.
# Cassio P.
#
# Descriptive Terms: Técnico, em
# -----------------------------------------------------------------------
# Bruno W.
# João Alair C.
#
# Descriptive Terms: Dados
# ----------------------------------------------------------
# Eduardo S.
# Regis M. S.
# Rafael E.
#
# Descriptive Terms:
# -----------------------------------------------------------------
# Anderson R.
# Vanderlei G.
# Bruno R.
# Kriscia M.
#
# Descriptive Terms: Técnico
# ------------------------------------------------
# João Alair C.
# Sergio dos Santos M.
# Arthur C.
# João Renato M.
#
# Descriptive Terms: Analista
# -----------------------------------------------------
# Ricardo P.
# William S.
# Gustavo B.
# Cassio M.
# Daniel C.
# Sandra M.
# Wesley M.
# Lorrana V.
# Arnaldo O.
# Arthur D.
# Juliano O.
# Renato L.
# Gabriela S.
# Daniel B.
# Maísa Santana Merlo C.
# Dyonatan Diogo Dias S.
# Amanda L.
# Layson D.
# MARCELO C.
# Gustavo M.
# wilker f.
# Nayara G.
# Maria Rita G.
# Igor T.
# Fabiola M.
# Ergildo D.
# Fernando Henrique G.
# Ricardo J.
# Pedro de Freitas S.
# Luana C.
# Fellipe G.
# Jennipher T.
# Henrique N.
# Lorena C.
# Jéssica F.
# Karoline G.
# Bruna F.
# Lucas V.
# Jonnathan R.
# Arthur Kenji I.
# Rosan B.
# Danilo C.
# Tiago F.
# Fillipe J.
# Bianca V.
# Silas M.
# Rodolfo d.
# Letícia R.
# Isabela B.
# Letícia M.
# Joao P.
# Rafael E.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Giselda S.
# Alexandre A.
# Rodrigo A.
# Romario S.
# Fernanda G.
# Ivan C.
# Renato C.
#
# Descriptive Terms: Manutenção
# -----------------------------------------------------
# Bruno R.
# Thiago Henrique M.
#
# Descriptive Terms: Engenheiro, de
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Douglas L.
# Josiemerson S.
# Andrêssa F.
# Luiz Felipe M.
# Guilherme C.
# Alana R.
# Wellyton M.
# Nielsen G.
# Vítor P.
# Johnata F.
# Augusto M.
# João Pedro F.
# Lucas M.
#
# Descriptive Terms: Engenheiro, de
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Douglas L.
# Josiemerson S.
# Andrêssa F.
# Luiz Felipe M.
# Guilherme C.
# Alana R.
# Wellyton M.
# Nielsen G.
# Vítor P.
# Johnata F.
# João Pedro F.
# Lucas M.
#
# Descriptive Terms: (Sub, Operações
# ---------------------------------------------------------
# Davi C.
# Davi C.
#
# Descriptive Terms: Officer, Chief
# -------------------------------------------------------------------------------------------------------------------------------
# Antônio C.
# Lucas B.
# Diego D.
# Rafael M.
# Marcelo Henrique D.
# DOUGLAS G.
#
# Descriptive Terms: 10, RH
# ---------------------------------------------
# Cláudia S.
# Cláudia S.
#
# Descriptive Terms: Engenheiro
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Josiemerson S.
# José Anceloann L.
# Andrêssa F.
# Guilherme B.
# Luiz Felipe M.
# Guilherme C.
# Alana R.
# Wellyton M.
# Vítor P.
# Johnata F.
# João Pedro F.
# Lucas M.
#
# Descriptive Terms: Developer
# -----------------------------------------------------------------------------------------
# Felipe B.
# Pedro P.
# Pedro P.
#
# Descriptive Terms:
# -------------------------------------------------------------------------------------------------------------------------
# Pedro Henrique P.
# Ricardo P.
# William S.
# Gustavo B.
# Gustavo B.
# Cassio M.
# Cassio M.
# Daniel C.
# Sandra M.
# Wesley M.
# Lorrana V.
# Arnaldo O.
# Arthur D.
# Arthur D.
# Juliano O.
# Renato L.
# Gabriela S.
# Daniel B.
# Andrêssa F.
# Maísa Santana Merlo C.
# Dyonatan Diogo Dias S.
# Amanda L.
# Layson D.
# MARCELO C.
# Guilherme C.
# Gustavo M.
# wilker f.
# Nayara G.
# Maria Rita G.
# Maria Rita G.
# Igor T.
# Fabiola M.
# Ergildo D.
# Fernando Henrique G.
# Fernando Henrique G.
# Ricardo J.
# Pedro de Freitas S.
# Luana C.
# Fellipe G.
# Jennipher T.
# Henrique N.
# Lorena C.
# Jéssica F.
# Michel M.
# Karoline G.
# Marco Túlio Z.
# Bruna F.
# Lucas V.
# Jonnathan R.
# Jonnathan R.
# Jonnathan R.
# Arthur Kenji I.
# Danilo C.
# Tiago F.
# Fillipe J.
# Bianca V.
# Bianca V.
# Silas M.
# Rodolfo d.
# Rodolfo d.
# Letícia R.
# Isabela B.
# Letícia M.
# Joao P.
# Joao P.
# Rafael E.
#
# Descriptive Terms: Sistemas
# ------------------------------------------
# Pablo A.
# Gustavo B.
# Cassio M.
# Andrêssa F.
# Maria Rita G.
# Fernando Henrique G.
# Michel M.
# Jonnathan R.
# Bianca V.
# Rodolfo d.
# Joao P.
#
# Descriptive Terms:
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Ricardo P.
# Cairo Kalil C.
# William S.
# Leandro S.
# Renato F.
# Douglas R.
# Luis J.
#
# Descriptive Terms:
# -----------------------------------------------------------------------------------------------------
# Bruno W.
# Rodrigo A.
# Fernanda G.
# Emmanuel C.
#
# Descriptive Terms: Analista
# --------------------------------------------------------------------
# Ricardo P.
# William S.
# Gustavo B.
# Cassio M.
# Daniel C.
# Sandra M.
# Wesley M.
# Lorrana V.
# Arnaldo O.
# Arthur D.
# Juliano O.
# Renato L.
# Gabriela S.
# Daniel B.
# Maísa Santana Merlo C.
# Dyonatan Diogo Dias S.
# Camila B.
# Amanda L.
# Layson D.
# MARCELO C.
# Gustavo M.
# wilker f.
# Nayara G.
# Maria Rita G.
# Igor T.
# Fabiola M.
# Ergildo D.
# Fernando Henrique G.
# Ricardo J.
# Pedro de Freitas S.
# Luana C.
# Fellipe G.
# Jennipher T.
# Henrique N.
# Lorena C.
# Jéssica F.
# Karoline G.
# Bruna F.
# Lucas V.
# Jonnathan R.
# Arthur Kenji I.
# Danilo C.
# Tiago F.
# Fernanda G.
# Fillipe J.
# Bianca V.
# Silas M.
# Rodolfo d.
# Letícia R.
# Isabela B.
# Letícia M.
# Joao P.
# Rafael E.
#
# Descriptive Terms: Comercial
# ----------------------------------------------------
# Guilherme I.
# Pedro Augusto d.
#
# Descriptive Terms: Programador
# ----------------------------------------------
# Andre S.
# wattyla c.
#
# Descriptive Terms: Foun
# ------------------------------------
# Antonio Pedro P.
# Filipe F.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------
# Yuri O.
# Wilson M.
# Amanda B.
# Matheus M.
# Fernanda L.
# Suze Correa de A. S.
# Emmanuel C.
#
# Descriptive Terms: Analista
# ----------------------------------------------------------------------------------
# Ricardo P.
# William S.
# Gustavo B.
# Cassio M.
# Daniel C.
# Sandra M.
# Wesley M.
# Lorrana V.
# Arnaldo O.
# Arthur D.
# Juliano O.
# Renato L.
# Gabriela S.
# Daniel B.
# Maísa Santana Merlo C.
# Dyonatan Diogo Dias S.
# Amanda L.
# Layson D.
# MARCELO C.
# Gustavo M.
# wilker f.
# Nayara G.
# Maria Rita G.
# Igor T.
# Fabiola M.
# Ergildo D.
# Fernando Henrique G.
# Ricardo J.
# Pedro de Freitas S.
# Luana C.
# Fellipe G.
# Jennipher T.
# Henrique N.
# Lorena C.
# Jéssica F.
# Karoline G.
# Bruna F.
# Lucas V.
# Jonnathan R.
# Arthur Kenji I.
# Danilo C.
# Tiago F.
# Fernanda G.
# Fillipe J.
# Bianca V.
# Juliana C.
# Silas M.
# Rodolfo d.
# Letícia R.
# Isabela B.
# Letícia M.
# Joao P.
# Rafael E.
#
# Descriptive Terms: e, Seleção, Recrutamento
# -----------------------------------------------------------------------
# Amanda L.
# Contato I.
#
# Descriptive Terms:
# --------------------------------------------------------------------------
# Lucas O.
# Leandro M.
# Vander A.
# José F.
# José F.
#
# Descriptive Terms: Engenheiro, Software, de
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Douglas L.
# Josiemerson S.
# Luiz Felipe M.
# Guilherme C.
# Alana R.
# Wellyton M.
# Vítor P.
# Johnata F.
# João Pedro F.
# Lucas M.
#
# Descriptive Terms: TI
# -------------------------------------------------
# Ricardo P.
# Ricardo P.
# Renato L.
# Wender C.
# wilker f.
# Pedro de Freitas S.
# Tiago F.
# Fillipe J.
#
# Descriptive Terms: Presi
# --------------------------------------
# Ivo Cesar P.
# Felipe C.
#
# Descriptive Terms: Engenheiro, Software, de
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Douglas L.
# Josiemerson S.
# Luiz Felipe M.
# Alana R.
# Wellyton M.
# Vítor P.
# Johnata F.
# João Pedro F.
# Lucas M.
#
# Descriptive Terms: Consultor
# ---------------------------------------------------------------------------------
# Leandro S.
# Renato F.
# Luis J.
#
# Descriptive Terms: Técnico
# -------------------------------------------------
# Sergio dos Santos M.
# Arthur C.
# João Renato M.
# Fernanda L.
#
# Descriptive Terms: Full
# --------------------------------------------
# Felipe B.
# Renan M.
# Pedro P.
#
# Descriptive Terms: Ensino, Superior, de, Professor
# ---------------------------------------------------------------------------------------
# Elaine R.
# William C.
# Marcelo M.
# Laurieny V.
#
# Descriptive Terms:
# -----------------------------------------------------------------------------------------
# Ricardo P.
# Cairo Kalil C.
# William S.
# Nilton S.
#
# Descriptive Terms: Humanos
# -----------------------------------------------------------------------------
# Jaquelaine M.
# Maísa Santana Merlo C.
# Kriscia M.
# Fabiola M.
# Lorena C.
# Karoline G.
#
# Descriptive Terms: Engenheiro, Software, de
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Douglas L.
# Luiz Felipe M.
# Alana R.
# Wellyton M.
# Vítor P.
# Johnata F.
# João Pedro F.
# Lucas M.
#
# Descriptive Terms: TI
# -----------------------------
# Ricardo P.
# Ricardo P.
# Renato L.
# Wender C.
# wilker f.
# Tiago F.
# Fillipe J.
#
# Descriptive Terms: Analyst
# ------------------------------------------------
# Marcela P.
# João Paulo M.
#
# Descriptive Terms: Analista, de
# -------------------------------------------------------------------------------
# Arthur D.
# Marco Túlio Z.
#
# Descriptive Terms: Assistente
# -----------------------------------------------
# Giselda S.
# Ivan C.
# Renato C.
#
# Descriptive Terms: Co
# -----------------------------
# Pablo Henrique S.
# Filipe F.
# Ruan B.
#
# Descriptive Terms: Engenheiro
# -------------------------------------------------
# José Anceloann L.
# Mateus Sebastião G.
#
# Descriptive Terms: Auxiliar
# ---------------------------------------------------
# Bruno W.
# Emmanuel C.
#
# Descriptive Terms: BI
# -----------------------------------
# Gustavo M.
# Nayara D.
# Flávio C.
#
# Descriptive Terms: Sócio
# ----------------------------------------
# Lucas O.
# Leandro M.
# José F.
#
# Descriptive Terms: Consultor
# -------------------------------------------------------------
# Renato F.
# Luis J.
#
# Descriptive Terms: Officer, Chief, Executive
# -----------------------------------------------------------------------------------------------------
# Antônio C.
# Diego D.
# Rafael M.
# DOUGLAS G.
#
# Descriptive Terms: Head, Of
# -----------------------------------------------------------------------------------------------
# JEANDERNEY F.
# Tacio M.
# Antônio Augusto S.
#
# Descriptive Terms: Supervisora
# ---------------------------------------------------
# Cláudia S.
# Danielle G.
# Ana Carolina F.
#
# Descriptive Terms: Engenheiro, Software, de
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Douglas L.
# Alana R.
# Wellyton M.
# Vítor P.
# Johnata F.
# João Pedro F.
# Lucas M.
#
# Descriptive Terms: Gerente
# -------------------------------------------------
# Sergio S.
# Cairo Kalil C.
# Pablo A.
# Wender C.
# Gabriel P.
# Fellipe P.
# Kriscia M.
# Luiz C.
# Lucas O.
# Thiago Henrique M.
# Heloisa C.
# Nilton S.
# Anderson L.
# Danilo L.
#
# Descriptive Terms: Sistemas
# -------------------------------------------------------------------------------------------
# Ricardo P.
# Gustavo B.
# Cassio M.
# Leonardo P.
# Andrêssa F.
# Maria Rita G.
# Fernando Henrique G.
# Luana C.
# Fellipe G.
# Michel M.
# Jonnathan R.
# Bianca V.
# Silas M.
# Rodolfo d.
# Joao P.
#
# Descriptive Terms: Engenheiro, Software, de
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Douglas L.
# Alana R.
# Vítor P.
# Lucas M.
#
# Descriptive Terms: Sistemas
# ---------------------------------------------------------------------------------
# Ricardo P.
# Leonardo P.
# Luana C.
# Fellipe G.
# Silas M.
#
# Descriptive Terms: Engenheiro, Software, de
# --------------------------------------------------------------------------------------------------------------------
# Douglas L.
# Alana R.
# Lucas M.
#
# Descriptive Terms: Officer, Chief, Executive
# ---------------------------------------------------------------------
# Diego D.
# Rafael M.
# DOUGLAS G.
#
# Descriptive Terms: Professor
# ----------------------------------------------
# Marcelo R.
# Maria Adriana V.
# Luiz Gustavo M.
# Alexsandro S.
# Mauricio E.
# Igor M.
# Cassio P.
#
# Descriptive Terms: vendas
# -----------------------------------------
# Yuri O.
# Guilherme B.
# Anderson L.
#
# Descriptive Terms: RH
# ---------------------------
# Cláudia S.
# Nayane R.
#
# Descriptive Terms: Head, Of
# ---------------------------------------------------------------
# JEANDERNEY F.
# Tacio M.
#
# Descriptive Terms: BI
# --------------------------------
# Gustavo M.
# Nayara D.
# Rafael E.
#
# Descriptive Terms: Sistemas
# -----------------------------------------------------------------
# Ricardo P.
# Leonardo P.
# Fellipe G.
# Silas M.
#
# Descriptive Terms: Diretor
# ----------------------------------------
# Felipe C.
# Carlos Á.
# Renato R.
# Marcílio T.
#
# Descriptive Terms: administrativo
# -----------------------------------------------------------------
# Fernanda L.
# Emmanuel C.
#
# Descriptive Terms: Dados
# -----------------------------------
# Eduardo S.
# Rafael E.
#
# Descriptive Terms: Foun
# -------------------------------
# Filipe F.
# Ruan B.
#
# Descriptive Terms: Sênior
# -----------------------------------------------------
# Ricardo P.
# William S.
#
# Descriptive Terms: Engenheiro, Software, de
# -------------------------------------------------------------------------------------
# Douglas L.
# Lucas M.
#
# Descriptive Terms: Sistemas
# --------------------------------------------------
# Ricardo P.
# Leonardo P.
# Fellipe G.
#
# Descriptive Terms: Junior
# --------------------------------------------------------
# Dyonatan Diogo Dias S.
# Bruna F.

# %% [markdown]
# ### Linkedin - Visualizando o agrupamento dos meus contatos por cargo

# %%
import os
import sys
import json
import webbrowser


HTML_TEMPLATE = 'dojo-tree.html'

data = {"label": "name", "temp_items": {}, "items": []}

clustered_contacts = cluster_contacts_by_title(CSV_FILE)

for titles in clustered_contacts:
    descriptive_terms = set(titles[0].split())
    for title in titles:
        descriptive_terms.intersection_update(set(title.split()))
    descriptive_terms = ', '.join(descriptive_terms)

    if descriptive_terms in data['temp_items']:
        data['temp_items'][descriptive_terms].extend([{'name': cc} for cc
                                                      in clustered_contacts[titles]])
    else:
        data['temp_items'][descriptive_terms] = [{'name': cc} for cc
                                                 in clustered_contacts[titles]]

for descriptive_terms in data['temp_items']:
    data['items'].append({"name": "%s (%s)" % (descriptive_terms,
                                               len(data['temp_items'][descriptive_terms]),),
                          "children": [i for i in
                                       data['temp_items'][descriptive_terms]]})

del data['temp_items']

# Open the template and substitute the data

if not os.path.isdir('out'):
    os.mkdir('out')

OUT = os.path.join('out', 'dojo-tree.html')

t = open(HTML_TEMPLATE).read()
f = open(OUT, 'w')
f.write(t % json.dumps(data, indent=4))
f.close()

webbrowser.open("file://" + os.path.join(os.getcwd(), OUT))
